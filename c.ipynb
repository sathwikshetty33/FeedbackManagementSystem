# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('./college_course_reviews.csv')
X=df.drop(columns=['review'],axis=0)
y=df["review"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from langchain.prompts import PromptTemplate
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(groq_api_key="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",temperature=0.9,model='openai/gpt-oss-20b')
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)
llm.invoke(prompt.format(product="colorful socks"))
# Out:
# AIMessage(content='Here are ten playful, memorable names—plus a quick note on why each could work for a colorful‑sock brand:\n\n| # | Name | Why it clicks |\n|---|------|--------------|\n| 1 | **Socktastic Spectrum** | “Socktastic” is a fun, all‑iterative word. “Spectrum” hints at a wide range of colors. |\n| 2 | **KaleidoKicks** | “Kaleido” evokes kaleidoscope patterns; “Kicks” feels casual, sporty. |\n| 3 | **RainbowStride** | A simple, easy‑to‑remember phrase that immediately signals colorful, comfortable feet. |\n| 4 | **VividSock Co.** | Short, professional, yet the “Vivid” word emphasizes bright hues. |\n| 5 | **ColorPop Socks** | “Pop” suggests a burst of color and energy—great for eye‑catching branding. |\n| 6 | **Hue & Sole** | A play on “hue” (color) and “sole” (foot), giving a subtle pun. |\n| 7 | **Chromatic Comfort** | Highlights both the colorful aspect and the cozy feel of socks. |\n| 8 | **PrismPeds** | “Prism” for colors, “Peds” (short for pedes) for feet—fun and mod
# ...
